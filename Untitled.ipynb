# %%
print("hello world!")
# Out:
# hello world!

# %%
import requests
from bs4 import BeautifulSoup

request = requests.get("https://www.ptt.cc/bbs/joke/index8350.html")
soup = BeautifulSoup(request.text,"html.parser")
sel = soup.select("div.title a")
for s in sel:
    print(s.text)
# total_title = soup.find_all('div', class_="tab-div")
# for s in total_title:
#     print(s.text)
# #     print(s.get('href'))


# for s in sel:
#     print(s["href"], s.text)
# Out:
# [趣圖] 林口運動中心
# [ＸＤ] 不幫小孩餵藥英文怎麼說
# [趣圖] 艾連葉卡與黃子佼
# [公告] 就可板規
# [閒聊] 置底閒聊文
# [公告] 發、推文提醒

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://www.ptt.cc/bbs/joke/index8350.html") #將網頁資料GET下來
soup = BeautifulSoup(r.text,"html.parser") #將網頁資料以html.parser
sel = soup.select("div.title a") #取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel
for s in sel:
    print(s["href"], s.text)
# Out:
# /bbs/joke/M.1602005687.A.E4D.html [公告] 就可板規
# /bbs/joke/M.1606831943.A.1BB.html [閒聊] 置底閒聊文
# /bbs/joke/M.1623640717.A.813.html [公告] 發、推文提醒

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.ptt.cc/bbs/guitar/index.html"
for i in range(5): #往回爬五頁
    r = requests.get(url)
#     print(r.status_code)#伺服器回應狀態碼 200代表沒問題
    soup = BeautifulSoup(r.text, "html.parser")
    sel = soup.select("div .title a")
    u = soup.select("div.btn-group.btn-group-paging a")
    print("本頁的url:"+url)
    url = "https://www.ptt.cc"+ u[1]["href"]
    for s in sel:
        print(s.text)
# Out:
# 本頁的url:https://www.ptt.cc/bbs/guitar/index.html
# [買賣] Duesenberg phonic
# [買賣] 售MartinD41.D28,Taylor612c,miniKoaPlus
# [問題] 請問這2把桃花心木吉他，哪個較好?
# [分享] 魔女宅急便：傷心的琪琪
# [新手] 吉他新手購琴指南 暨 試琴禮儀
# [公告] 吉他板規
# [問題] Gibson custom vs r9
# 本頁的url:https://www.ptt.cc/bbs/guitar/index1572.html
# [買賣] 售Alvarez古典電吉他(全單)+周邊設備
# [買賣] Edwards E-FR-145GT 視覺系大搖座黑色琴
# Re: [買賣] Sigma JM-SG45 (類J45)
# [買賣] 售Martin D41,Taylor612c,GSminiKoaPlus
# [討論] Taylor原廠弦改用D'Addario XS的原因？
# [買賣] 簡易吉他架
# [買賣] FGN - Neo Classic NLS11GMP
# [問題] 左手指頭微震動感
# [分享] 兔田PEKORA BGM Fingerstyle cover
# [討論] 搖滾已死？
# [板友] 找人平時一起練習吉他 唱歌
# [問題] Gibson custom vs r9
# [贈送] 新北三峽 木吉他
# [買賣] Zemaitis日廠琴 24格LP形薄琴身
# [分享] GnR - November Rain guitar solo cover
# [買賣] 售 Taylor AD17 電木吉他
# Re: [買賣] Huss & Dalton 沈水紅木/可可波蘿
# [買賣] Edwards E-FR-145GT 視覺系大搖座黑色琴
# [活動] John Mayer簽名款PRS SE SILVER SkY
# 本頁的url:https://www.ptt.cc/bbs/guitar/index1571.html
# [教學] 桃園電吉他 木吉他教學
# [問題] 第一顆電吉他音箱選擇(已爬過板上文章)
# [問題] 外國網購吉他問題（複雜）
# [教學] 台北Swingcat音樂工作室 永和/頂溪
# ...

# %%
import requests
r = requests.Session()
payload={
    "from":"/bbs/Gossiping/index.html",
    "yes":"yes"
}
r1 = r.post("https://www.ptt.cc/ask/over18?from=%2Fbbs%2FGossiping%2Findex.html",payload)
r2 = r.get("https://www.ptt.cc/bbs/Gossiping/index.html")
print(r2.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# ...

# %%
import requests
picture = requests.get('https://imgur.dcard.tw/N2k5kV2m.jpg')
img2 = pic.content
pic_out = open('img1.pgn','wb'
              )
